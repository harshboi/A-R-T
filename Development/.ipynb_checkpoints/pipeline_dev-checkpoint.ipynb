# %%
import twint
file = open("../security_tags.txt","r")
arr = []
line1 = file.readlines()
for x in line1:
    arr.append(x)
file.close()

# %%
for i in range(len(arr)):
    arr[i] = arr[i][1:]

# %%
# Open and Clear file test1.json
file = open("./test1.json","w")
file.close()

# %%
import twint

def get_followers (username):
    c = twint.Config()
    c.Username = username
    c.Store_object = True
    c.Limit = 40
    c.Output = "./test.json"
    c.Store_json = True
    twint.run.Lookup(c)
#     twint.run.Followers(c)
#     return twint.output
print(get_followers("briankrebs"))

# %%
# # clear file
# #Twint Search
# for i in range(len(arr)):
#     d = twint.Config()
#     d.Search = arr[i]
#     d.Limit = 50
#     # d.Store_csv = True
#     d.Store_object = True
#     d.Store_json = True
#     d.Output = "./test1.json"
#     # d.Database = "tweets.db"


#     x = twint.run.Search(d)

# %%
import twint

# Twint Search
d = twint.Config()
d.Search = "security"
# d.Search = "endpoint AND seminar"
d.Limit = 1000
# d.Store_csv = True
d.Store_object = True
d.Store_json = True
d.Output = "./test1.json"
# d.Database = "tweets.db"

x = twint.run.Search(d)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-47-56de4129046a> in <module>
#      12 # d.Database = "tweets.db"
#      13
# ---> 14 x = twint.run.Search(d)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/twint/run.py in Search(config, callback)
#     286     config.Profile = False
#     287     config.Profile_full = False
# --> 288     run(config, callback)
#     289     if config.Pandas_au:
#     290         storage.panda._autoget("tweet")
#
# ~/opt/anaconda3/lib/python3.7/site-packages/twint/run.py in run(config, callback)
#     207 def run(config, callback=None):
#     208     logme.debug(__name__+':run')
# --> 209     get_event_loop().run_until_complete(Twint(config).main(callback))
#     210
#     211 def Favorites(config):
#
# ~/opt/anaconda3/lib/python3.7/asyncio/base_events.py in run_until_complete(self, future)
#     564         future.add_done_callback(_run_until_complete_cb)
#     565         try:
# --> 566             self.run_forever()
#     567         except:
#     568             if new_task and future.done() and not future.cancelled():
#
# ~/opt/anaconda3/lib/python3.7/asyncio/base_events.py in run_forever(self)
#     519         self._check_closed()
#     520         if self.is_running():
# --> 521             raise RuntimeError('This event loop is already running')
#     522         if events._get_running_loop() is not None:
#     523             raise RuntimeError(
#
# RuntimeError: This event loop is already running
# 1260842607384690688 2020-05-14 01:01:17 PDT <Bestreetsafe> #England star @dele_official was held at knifepoint during burglary at his £2m north London home earlier this week.  Take proper security precautions to keep yourself safe, unfortunately not everybody is on your side.  https://www.dailymail.co.uk/sport/sportsnews/article-8316869/Tottenham-England-star-Dele-Alli-held-knifepoint-robbery.html …
# 1260842606151569408 2020-05-14 01:01:17 PDT <InfoSecHotSpot> XM Cyber, the multi-award-winning breach and attack simulation (BAS) leader, was recognized as a "Cool Vendor" in Gartner's May 2020 "Cool Vendors in Security Operations and Threat Intelligence" ...  http://twib.in/l/RLzM6nK8Xzae  via @InfoSecHotSpot pic.twitter.com/iE4q9nyXkX
# 1260842602733006849 2020-05-14 01:01:16 PDT <Kirbieber> Ganito po ka archaic yung mobile app ng @hsbc vs other banks which already have biometric security built-in.  pic.twitter.com/SCj0oaoYXN
# 1260842601566986247 2020-05-14 01:01:16 PDT <AU_Careers> Looking to start a career in security? Don’t miss your opportunity to become a Armed Security Officer. Start your phenomenal career today in Las Vegas, NV.  https://bit.ly/2zzxvVl  #HiringNow #Veterans
किसानों_को_आत्मनिर्भर_पैकेज_में_हिस्सा_दो #DeclareFarmersPackage
# 1260835403545956352 2020-05-14 00:32:40 PDT <dircasacalora> Top story: Security Check Required  https://www.facebook.com/NoticierosTelevisacom/videos/635302427327980/ …, see more  http://tweetedtimes.com/dircasacalora?s=tnp …
# 1260835387213217795 2020-05-14 00:32:36 PDT <Rajs_Dama> For marginal and landless farmers govt must ensure food security by Implememt minimum Income guarantee by gives them part in आत्मनिर्भर पैकेज For their survival in this situation of pandemic.  #किसानों_को_आत्मनिर्भर_पैकेज_में_हिस्सा_दो #DeclareFarmersPackage
# 1260835382427553795 2020-05-14 00:32:35 PDT <Debasis52252186> Since then, I have not been able to receive any finance from any bank to set up a new project. Often banks choose security against their finance instead of viability of the project. That is why there are increasing no. of NPAs with lot of financial institutions.
# 1260835375259492352 2020-05-14 00:32:33 PDT <DecolonizingThe> I’m not white & been hassled 4 being out walking @ night. When asked 4 ID I ask: “Is my membership card 4 the Law Society of Upper Canada acceptable - it’s a photo ID & gets me in2 the Supreme Ct of 🇨🇦 w/out a security check?” DWI (Indigenous) is also an offence apparently.
# 1260835358822010880 2020-05-14 00:32:29 PDT <TeamYouTube> (2/2) Note: Phone numbers are considered as private information. For your security, we recommend deleting your tweet.
# 1260835351997734917 2020-05-14 00:32:27 PDT <Kurisitaru> They don’t even have to tell you. Go to a mall and just watch the security guards follow POC around like they are about to commit a crime. If you don’t see racism in your day to day, you’re blind AF.   But yeah, billions of planets. At least one has to have a life from, right?
# 1260835348072075264 2020-05-14 00:32:26 PDT <per_incuriam> And slashing tariffs on US agricultural imports could undercut UK farmers that have higher welfare and production standards.  Still. It’s not like that we‘d ever need UK farmers to ensure our food security?  Is it @trussliz? pic.twitter.com/r3TNjXWX4d
# 1260835340039921664 2020-05-14 00:32:24 PDT <roka_aardal> Not done yet, preparing a "Test Rationale Matrix" to use in workshops, discussions, fun. Place a test then consider why do that type of test - creates discussion, enlightenment? #security #testing #pentesting /1 pic.twitter.com/bnSA0FJvSq
# 1260835336868909056 2020-05-14 00:32:24 PDT <quantum1021> via @NYTimes Judge Appoints Outsider to Take On Justice Dept. in Flynn Case  A retired judge will also examine whether the former national security adviser committed perjury.  https://www.nytimes.com/2020/05/13/us/politics/michael-flynn-john-gleeson-judge.html?referringSource=articleShare …
# 1260835324063887361 2020-05-14 00:32:21 PDT <matteocollina> I agree. Deno's fetch is likely not standard compliant for security and caching, so we can likely do something similar.
# 1260835313909366784 2020-05-14 00:32:18 PDT <MidhunrajRajanT> Thank You, Also can you clarify whether synchronized security will work with Sophos SG UTM.
# 1260835306766585858 2020-05-14 00:32:16 PDT <CoupeBad> @staceyabrams @msnbc @nbc @nbcnewyork @nbcnews @NBCRadioNetwork @nysenate @nygovcuomo @AP @thedemocrats @dscc @tomperez @hillaryclinton Forcing Disingenuous 4x Social Security Attacker On Multiple YouTube Videos Pre_Teen Child Molester @joebiden on Voters https://www.youtube.com/watch?v=GI1xf7Ji000 …
# 1260835289628631040 2020-05-14 00:32:12 PDT <SMuzk> @edmnangagwa @DrTaxs @CyrilRamaphosa @hagegeingob @UNHumanRights The abduction of Zimbabwe opposition activists and Member of Parliament by the security forces of Zimbabwe is concerning in terms of human rights abuses help @nelsonchamisa https://twitter.com/UKinZimbabwe/status/1260828421728473090 …
# 1260835289024663556 2020-05-14 00:32:12 PDT <Aleins19051201> via @NYTimes Judge Appoints Outsider to Take On Justice Dept. in Flynn Case  A retired judge will also examine whether the former national security adviser committed perjury.  https://www.nytimes.com/2020/05/13/us/politics/michael-flynn-john-gleeson-judge.html?referringSource=articleShare …
# 1260835281579606016 2020-05-14 00:32:10 PDT <somcity> #Security #Covid19 https://twitter.com/Paula_Piccard/status/1260588372369854464 …
# 1260835271920107520 2020-05-14 00:32:08 PDT <KhenzaNafisa> This is a amazing project and it's so obvious that they prioritize the security and transparency of this project.
# 1260835251623989248 2020-05-14 00:32:03 PDT <fluxfm_berlin> 14.05. 09:32 Uhr: Sophie Hunger "Security Check"
# 1260835245085151232 2020-05-14 00:32:02 PDT <DailyLibber> Thats the plan, but other than that all I know is its easier to get security cameras in the area than it is to get internet. The situation has opened my eyes up to some things.
# 1260835242803376128 2020-05-14 00:32:01 PDT <MBITJapan> The Firewall: The foundation for a robust Security Platform  https://oal.lu/yr8dh  pic.twitter.com/UbxuhQBxD2
# 1260835231373770752 2020-05-14 00:31:59 PDT <PixelSakura> Good, this joke never gets old lol
# 1260835204186484736 2020-05-14 00:31:52 PDT <sallywt> They broke in through the roof of the tack room. Took 20 saddles. We have now reinforced the roof and put further security measures in place. Unfortunately it appears we aren’t the only ones to be robbed.
# 1260835190064271361 2020-05-14 00:31:49 PDT <eurosecurity> @Der_Postillon 🚧 BER Bausimulator👷: Der epische Trailer zum ersten Postillon-Spiel fürs Smartphone https://www.der-postillon.com/2020/05/ber-bausimulator-trailer.html …
# 1260835187195121665 2020-05-14 00:31:48 PDT <PaidDuess> Its not something you’d know about unless you have money or are around people like so. I only know because i do celebrity security and this liquor was on hand on a couple different occasions
# 1260835174411055104 2020-05-14 00:31:45 PDT <GreenGreenwich> Jobs which were found to have high death rates included security guards, care workers, construction workers, plant operatives, cleaners, taxi drivers, bus drivers, chefs and retail workers.   Yet aren’t most of the above back to work?  https://www.theguardian.com/uk-news/2020/may/13/pensioners-34-times-more-likely-to-die-of-covid-19-than-working-age-brits-data-shows?CMP=Share_iOSApp_Other …
# 1260835161203236864 2020-05-14 00:31:42 PDT <Amit70545632> That was a security flaw, which arrested terrorist DSP Devinder Singh revealed to extremists. He was posted in pulwama that time. Stop demonising our armed forces and giving clean chit to pakistan

# %%
# Search terms
# 0-day AND exploit
# “0-day”, “CVE-“, “CVE-2018-*”, “CVE-2020-*”
# usernames:
# kibbsy
# it_securitynews
# msftsecurity

# %%
# x = twint.run.Search(d)
# twint -u noneprivacy --csv --output "/Users/psingh4/harsh/test4.json" --lang en --translate --translate-dest it --limit 100

# %%
# d.__dict__.keys()

# %%
# twint.run.Search(d)
# twint.output

# %%
################################################################################################
# Loads file written from Twint
################################################################################################

f= open("./test1.json","r",errors='ignore')
line1 = f.readlines()
arr = []
for x in line1:
    arr.append(x)
f.close()

# %%
################################################################################################
# Fixes Error from Twint where braces and commas were missing in the json
################################################################################################
arr.insert(0,"[")
arr.append(']')
for i in range(1,len(arr)-2):
    arr[i] = arr[i][:-1] + "," + arr[i][-1:]

# %%
################################################################################################
# Writes the corrected files to json
################################################################################################
file = open("./test.json","w")
for i in range(len(arr)):
    file.write(arr[i])
file.close()

# %%
################################################################################################
# Loads corrected JSON file
################################################################################################

f= open("./test.json","r",errors='ignore')
line1 = f.readlines()
data = []
for x in line1:
    data.append(x)
f.close()

# %%
################################################################################################
# Removes Non-ASCII characters
################################################################################################
for i in range(len(data)):
    data[i] = (''.join([i if ord(i) < 128 else ' ' for i in str(data[i])]))

# %%
file = open("./data.json","w")
for i in range(len(data)):
    file.write(data[i])
file.close()

# %%
import json
with open("./data.json", "r",errors='ignore') as read_file:
    data = json.load(read_file)

# %%
data[10]['tweet']
# is_english(str(data[130]['tweet']))
# Out:
# 'Data of 9 million customers of the Russian courier service CDEK leaked -  https://www.redpacketsecurity.com/data-of-9-million-customers-of-the-russian-courier-service-cdek-leaked/  \n#OSINT #Security #Threatintel #cybersecurity'

# %%
translator.detect("Hello").lang == 'en'

# %%
################################################################################################
# Google Trans model for checking if a tweet is english or not, unpoisons the training data
################################################################################################

# ! pip install googletrans
from googletrans import Translator
translator = Translator(service_urls=['translate.google.com'])

def is_english(sentence):
    if translator.detect(sentence).lang == 'en':
        return True
    else:
        return False
    
with open("../classified_tweets.json", "r",errors='ignore') as read_file:
    data = json.load(read_file)

i=0
skip = [130]
while i <= len(data):
#     print(i)
    if (i in skip): continue
    if is_english(data[i]['tweet']) == False:
        print(data[i]['tweet'])
        data.pop(i)
    else: i+= 1

# %%
################################################################################################
# MySql connection established
################################################################################################

import mysql.connector
mydb = mysql.connector.connect(user='admin', password='Private2712!',
                              host='database-1.cok63qqiofsd.us-east-1.rds.amazonaws.com',
                              database='data')
mycursor = mydb.cursor()

# %%
###############################################################################################################
# Insert records from Twint into Relation DB, see relation schema code on GitHub for table structure
# Requires the JSON file with metadata
###############################################################################################################

sql = """INSERT INTO classified_tweets (relevant, created_at, conversation_id, id, date, time, timezone, user_id, username, name, place, tweet, mentions, urls, replies_count, 
        retweets_count, likes_count, hashtags, cashtags, link, retweet, video, near, geo, source, user_rt_id, user_rt, retweet_id,
        retweet_date, translate, trans_src, trans_dest, photos, reply_to) VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, 
        # %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s)"""

val = []
for i in range(1, len(data)):
    val.append((1, data[i]['created_at'], data[i]['conversation_id'], str(data[i]['id']), data[i]['date'], data[i]['time'], data[i]['timezone'], data[i]['user_id'], data[i]['username'],
      data[i]['name'], data[i]['place'], data[i]['tweet'], str(data[i]['mentions']), str(data[i]['urls']), data[i]['replies_count'],
      data[i]['retweets_count'], data[i]['likes_count'], str(data[i]['hashtags']), str(data[i]['cashtags']), data[i]['link'], data[i]['retweet'],
      data[i]['video'], data[i]['near'], data[i]['geo'], data[i]['source'], data[i]['user_rt_id'], data[i]['user_rt'],
      data[i]['retweet_id'], data[i]['retweet_date'], data[i]['translate'], data[i]['trans_src'], data[i]['trans_dest'],str(data[i]['photos']), 
       str(data[i]['reply_to'])))
    
mycursor.executemany(sql, val)

mydb.commit()

print(mycursor.rowcount, "record inserted.")

mydb.close()

# %%
###############################################################################################################
# Cell to see how the data looks at in val (Outdated, more attributes being captured now)
###############################################################################################################

val = []
for i in range(len(data)):
    val.append((data[i]['created_at'], data[i]['conversation_id'], data[i]['date'], data[i]['time'], data[i]['timezone'], data[i]['user_id'], data[i]['username'],
      data[i]['name'], data[i]['place'], data[i]['tweet'], str(data[i]['mentions']), str(data[i]['urls']), data[i]['replies_count'],
      data[i]['retweets_count'], data[i]['likes_count'], str(data[i]['hashtags']), str(data[i]['cashtags']), data[i]['link'], data[i]['retweet'],
      data[i]['video'], data[i]['near'], data[i]['geo'], data[i]['source'], data[i]['user_rt_id'], data[i]['user_rt'],
      data[i]['retweet_id'], data[i]['retweet_date'], data[i]['translate'], data[i]['trans_src'], data[i]['trans_dest'],0,str(data[i]['photos']), 
       str(data[i]['reply_to'])))

# %%
# mydb.commit()
# !pip install tensorflow
# print(mycursor.rowcount, "record inserted.")

# %%
# !pip install bert-serving-server
# !pip install bert-serving-client

# %%
###############################################################################################################
# Using nltk to display tagging of words
###############################################################################################################

import nltk
sentence = "NSA exploit EternalRomance with CVE-2019-897 'formed basis for alleged Chinese tool' - iTWire Researchers Mark Lechtik and Nadav Grossman said in first offered NSA exploits that the hacking group, known variously as APT3 and Gothic Panda, had based its exploitation tool, https://ift.tt/2HRG9js"
# sentence = "NowBrowsing: ESLint dependencies are vulnerable (ReDoS and Prototype Pollution) · CVE-2020-7598 · GitHub Advisory Database:  https://github.com/advisories/GHSA-7fhm-mqm4-2wp7"
tokens = nltk.word_tokenize(sentence)
tagged = nltk.pos_tag(tokens)
tagged

# %%
###############################################################################################################
# Using Spacy to display tagging of words
###############################################################################################################

# !python -m spacy download en
# !python -m spacy download en_core_web_sm

import spacy
nlp = spacy.load('en_core_web_sm')  # Loads the english model for spacy

# %%
# sentence = "NSA exploit EternalRomance with CVE-2019-897 'formed basis for alleged Chinese tool' - iTWire Researchers Mark Lechtik and Nadav Grossman said in first offered NSA exploits that the hacking group, known variously as APT3 and Gothic Panda, had based its exploitation tool, https://ift.tt/2HRG9js"
sentence = "NowBrowsing: ESLint dependencies are vulnerable (ReDoS and Prototype Pollution) · CVE-2020-7598 · GitHub Advisory Database:  https://github.com/advisories/GHSA-7fhm-mqm4-2wp7"
doc = nlp(sentence)
print("The sentence is: ", sentence)
print([ent for ent in doc.ents])
# for ent in doc.ents:
# doc

# %%
print("Noun phrases:", [chunk.text for chunk in doc.noun_chunks])

# %%
print("Verbs:", [token.lemma_ for token in doc if token.pos_ == "VERB"])

# %%
# !pip install -U bert-serving-server bert-serving-client

# %%
# Run on termninal if Bert Server and Client installed
# !bert-serving-start -model_dir /tmp/english_L-12_H-768_A-12/ -num_worker=4

# %%
# from bert_serving.client import BertClient
# bc = BertClient()
# bc.encode(['First do it', 'then do it right', 'then do it better'])

# %%
# first neural network with keras tutorial
import numpy as np
from numpy import loadtxt
from keras.models import Sequential
from keras.layers import Dense
# load the dataset
data = np.load('./tweet_encodings.npy')
label = np.load('./maybeincludedlabels.npy')
# define the keras model
model = Sequential()
model.add(Dense(400, input_dim=768, activation='relu'))
model.add(Dense(200, activation='relu'))
model.add(Dense(2, activation='softmax'))
# compile the keras model
model.compile(loss='sparse_categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
# fit the keras model on the dataset
# evaluate the keras model

# %%
model.fit(data, label, epochs=10, batch_size=1, validation_split=0.25)

# %%
import sklearn
from sklearn.linear_model import LogisticRegression
len(data), len(label)

# %%
clf = LogisticRegression(random_state=1).fit(data[:-900], label[:-900])

# %%
clf.score(data[-900:], label[-900:])

# %%
y_pred = clf.predict(data[-800:])

# %%
y_true = label[-800:]

# %%
from sklearn import metrics

accuracy_score = metrics.accuracy_score(y_true,y_pred)
print("Accuracy score: {}".format(accuracy_score))
fpr, tpr, thresholds = metrics.roc_curve(y_true,y_pred,pos_label = 1)
auc_score = metrics.auc(fpr,tpr)
print("AUC: {}".format(auc_score))

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn import svm
from sklearn import metrics
import numpy as np
import sys
import pdb
import matplotlib.pyplot as plt


def print_metrics(y_true,y_pred):
    accuracy_score = metrics.accuracy_score(y_true,y_pred)
    print("Accuracy score: {}".format(accuracy_score))
    fpr, tpr, thresholds = metrics.roc_curve(y_true,y_pred,pos_label = 1)
    auc_score = metrics.auc(fpr,tpr)
    print("AUC: {}".format(auc_score))
    return accuracy_score,auc_score

def logistic_regression(x_train,x_test,y_train,y_test):
    logisticRegr = LogisticRegression()
    logisticRegr.fit(x_train,y_train)
    predictions = logisticRegr.predict(x_test)
    print_metrics(y_test,predictions)


def support_vector(x_train,x_test,y_train,y_test):
    model = svm.SVC()
    model.fit(x_train,y_train)
    predictions = model.predict(x_test)
    print_metrics(y_test,predictions)

def torch_label_creator(label):
    if label.item() == 1:
        return torch.tensor([1,0])
    else:
        return torch.tensor([0,1])

    #plot test accuracies and auc over epochs    
    plt.plot(test_accuracies)
    plt.ylabel('Accuracy')
    plt.xlabel('Epoch')
    plt.title('Test Accuracy vs Epoch')
    plt.show()
    plt.plot(test_auc)
    plt.ylabel('AUC')
    plt.xlabel('Epoch')
    plt.title('Test AUC vs Epoch')
    plt.show()

# %%
encodings = np.load('tweet_encodings.npy')
labels = np.load('maybeincludedlabels.npy')
x_train,x_test,y_train,y_test = train_test_split(encodings,labels, test_size=0.25, random_state=0)

# %%
logistic_regression(x_train,x_test,y_train,y_test)

# %%
clf.score(x_test, y_test)

# %%
from neo4j import GraphDatabase
import json
#Indicate to driver where neo4j is running
driver = GraphDatabase.driver("bolt://localhost",auth=("test_user","password"), encrypted=False)
#Parse data
counter = 0
with open("./data.json",'r') as file:
    #Need to make a session where you will run all your cypher queries
    with driver.session() as session:
        tx = session.begin_transaction()
        noun_count = 0
        count = 0
        for line in file.readlines(): #can limit lines with [:100] after ()
            if (line == "[\n" or line == "]"):
                continue
            item = json.loads(line[:-2])
            sen_noun = noun[noun_count]
            # Stores the Tweets nouns in the graph db (Outdated). Here a node is a collection of nouns without a distinct identity
            tx.run('''CREATE (a:Tweet{id:$value.id,date:$value.date,train_id:$value.train_id,nouns:$sen_noun})''',
                   parameters={'tweet': item}, value=item, sen_noun=sen_noun) # add parameters here
            #Batch processing to run 1000 tweets as a time as these commits are quite time intensive
            count += 1
            noun_count += 1
#             tx.commit()
#             break   # UNCOMMENT IF PUSHING MULTIPLE ROWS/NODES OF DATA 
            if count > 1000:
                tx.commit()
                tx = session.begin_transaction()
                count = 0
        tx.commit()

# %%
########################################################################################################
# Cypher code for graph db (Some example queries)
########################################################################################################

# Match (a:Tweet) where 'Malware' in a.nouns return a

# Match (a:Tweet), (b:Tweet) where 'Malware' in a.nouns and 'Malware' in b.nouns create (a)-[r:Malware]->(b) return r

# '''WITH {tweet} AS Tweet
#     Merge (a:Tweet{id:$value.id,date:value.date,train_id:value.train_id})
#     Merge (d:Date{date:value.date})
#     Merge (a)-[:SAME_DATE]->(d)'''

# '''CREATE (a:Tweet{id:$value.id,date:$value.date,train_id:$value.train_id,nouns=sen_noun})'''

# '''start n=node(*) return n'''

# MATCH (n:Tweet)-[m:Malware]-(b:Tweet)
#     WHERE n.id = 1223562341540859904
#     REturn b
#     order by b.date

# Create (x:Tweet{ id:1, noun: 'test', key: 'Value', last10DaysCount:[10], last10DaysDate:["12-10-2019"]  }) return x
# match (x:Tweet {id: 10}) set x.last10DaysDate = x.last10DaysDate[0..1] + ['12-09-2019'] + x.last10DaysDate[1..]  return x
# match (x:Tweet {id:10}) set x.last10DaysCount = x.last10DaysCount[..2] + (x.last10DaysCount[2]+10) + x.last10DaysCount[3..] return x

# %%
########################################################################################################
# Connection to graph db (Neo4j) established
########################################################################################################

from neo4j import GraphDatabase
import json
#Indicate to driver where neo4j is running
driver = GraphDatabase.driver("bolt://localhost:7687",auth=("test_user","password"), encrypted=False)

# %%
import json

data = {}
with open("./datasets/complete_data.json") as f:
    data = json.load(f)

# %%
# Note, apply some more feature engineering such as removing stop words from a sentence
# techniques laid out here: https://www.analyticsvidhya.com/blog/2019/08/how-to-remove-stopwords-text-normalization-nltk-spacy-gensim-python/

import spacy
nlp = spacy.load('en_core_web_sm')
sentence = "CVE-2019-897 NSA exploit EternalRomance 'formed basis for alleged Chinese tool' - iTWire Researchers Mark Lechtik and Nadav Grossman said in first offered NSA exploits that the hacking group, known variously as APT3 and Gothic Panda, had based its exploitation tool, https://ift.tt/2HRG9js"
doc = nlp(sentence)
print("The sentence is: ", sentence)
# print([ent for ent in doc.ents])
# for ent in doc.ents:
# doc
print("Noun phrases:", [chunk.text for chunk in doc.noun_chunks])
# Out:
# The sentence is:  CVE-2019-897 NSA exploit EternalRomance 'formed basis for alleged Chinese tool' - iTWire Researchers Mark Lechtik and Nadav Grossman said in first offered NSA exploits that the hacking group, known variously as APT3 and Gothic Panda, had based its exploitation tool, https://ift.tt/2HRG9js
# Noun phrases: ['CVE-2019-897 NSA', "EternalRomance 'formed basis", "alleged Chinese tool' - iTWire Researchers Mark Lechtik", 'Nadav Grossman', 'the hacking group', 'APT3', 'Gothic Panda', 'its exploitation tool', 'https://ift.tt/2HRG9js']

# %%
########################################################################################################
# Uses Spacy for finding nouns, named entity recognition
# Old results from spacy, without removing stop words
########################################################################################################

import spacy
from spacy.lang.en import English

# Option = 1 => Get all Nouns, Oprion = 2 => Get position entities
def get_all_nouns( data, option ):
    nlp = spacy.load('en_core_web_sm')
    sentence = data.replace("-", " ").replace("#", " ")
    doc = nlp(sentence)
    if option == 1:
        tagged = [chunk.text for chunk in doc.noun_chunks]
        return tagged
    else:
        pos_ent = []
        for ent in doc.ents:
            pos_ent.append(ent.text)
#             print(ent.text, ent.label_)
        return pos_ent

########################################################################################################
# Uses Spacy for finding nouns, named entity recognition
########################################################################################################
# import spacy

# nlp = spacy.load('en_core_web_sm')

# noun = []
# noun_from_tweet = []
# for i in range(len(data)):
#     if data[i]['relevant'] == 0:
#         continue
#     sen_noun = []
#     sentence = data[i]['text']
#     doc = nlp(sentence)
#     tagged = [chunk.text for chunk in doc.noun_chunks]
#     noun_from_tweet.append(tagged)
#     for nouns in tagged:
#         noun.append(nouns)
# #     noun.append(sen_noun)

# %%
########################################################################################################
# Uses Spacy for finding nouns, named entity recognition
# NEW results from spacy, after removing stop words
########################################################################################################

def get_nouns_wo_stop_words ( data, option ):
    nlp = English()

    my_doc = nlp(data.replace("-", " ").replace("#", " "))
    # Create list of word tokens
    token_list = []
    for token in my_doc:
        token_list.append(token.text)
    from spacy.lang.en.stop_words import STOP_WORDS

    # Create list of word tokens after removing stopwords
    filtered_sentence =[] 

    for word in token_list:
        lexeme = nlp.vocab[word]
        if lexeme.is_stop == False:
            filtered_sentence.append(word)    # Contains the sentence without stop words
    # print(token_list)
    # print(filtered_sentence) 

    new_text = filtered_sentence[0] + " "
    for i in range(1,len(filtered_sentence)):
        new_text += filtered_sentence[i] + " "

    nlp = spacy.load('en_core_web_sm')

    #  "nlp" Object is used to create documents with linguistic annotations.
    noun = []
    sen_noun = []
    sentence = new_text
    doc = nlp(sentence)
    if option == 1:
        tagged = [chunk.text for chunk in doc.noun_chunks]
        return tagged
    else:
        pos_ent = []
        for ent in doc.ents:
            pos_ent.append(ent.text)
#             print(ent.text, ent.label_)
        return pos_ent

# %%
########################################################################################################
# Uses NLTK for finding nouns
########################################################################################################

# nltk.download()    #Crashes on Mac, check on win machine
# Bottom two fixes the issue by not using nltk
# nltk.download('averaged_perceptron_tagger')
# nltk.download('english')

# This cell for nltk

import nltk

def nltk_nouns(data):
    nlp = spacy.load('en_core_web_sm')
    sen_noun = []
    sentence = data
    tokens = nltk.word_tokenize(sentence)
    tagged = nltk.pos_tag(tokens)
    for j in range(len(tagged)):
        if (tagged[j][1] == 'NNP'):
            sen_noun.append(tagged[j][0])
    return sen_noun

# %%
data[0]['relevant']
# Out:
# 1

# %%
##############################################################################################################
# Test between with and without stop words noun results for spacy
##############################################################################################################

# Collecting 100 tweets
counter = 0
data_list = []
for i in range(len(data)):
    if data[i]['relevant'] == 1:
        data_list.append(data[i])
        counter += 1
    if (counter == 100): break
# data[2788]
# get_all_nouns(data[2788])

results = []
for i in range(100):
    results.append((get_all_nouns(data_list[i]['text'], 2), get_nouns_wo_stop_words(data_list[i]['text'], 2)))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-166-8168ebab7c2f> in <module>
#      16 results = []
#      17 for i in range(100):
# ---> 18     results.append((get_all_nouns(data_list[i]['text'], 2), get_nouns_wo_stop_words(data_list[i]['text'], 2)))
#
# KeyError: 'text'

# %%
##############################################################################################################
# Combining results with and without stop words
##############################################################################################################

# Results is 
def combine_stopwords_spacey(results):
    all_named_entities = []
    for j in range(len(resluts)):
        x = set()
        for i in range(len(results[28][0])):
            x.add(results[j][0][i])
        for i in range(len(results[28][1])):
            x.add(results[j][1][i])
        all_named_entities.append(x)

# %%
##############################################################################################################
# Print results for comparing w/wo spacy
##############################################################################################################

# results[28]
(get_all_nouns(data_list[28]), get_nouns_wo_stop_words(data_list[28]))

# %%
# results[30:50]
# data
# Note have all occurences of zero day collapse to 0-day node in graph db, find other occurences of such words

# %%
import json
with open("../datasets/classified_tweets.json", "r",errors='ignore') as read_file:
    data = json.load(read_file)

# %%
##############################################################################################################
# Collecting day count for named entities/nouns - Extremely Time Consuming
##############################################################################################################
from collections import defaultdict

all_nouns = []
noun_day_count = defaultdict(lambda: defaultdict(lambda:0))
for i in range(len(data[:500])):
#     nouns = get_all_nouns(data[i]['tweet'], 2)
    nouns = nltk_nouns(data[i]['tweet'])
    for noun in nouns:
        noun_day_count[noun][data[i]['date']] += 1
    all_nouns.append(nouns)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-179-c9544d495adf> in <module>
#       8 for i in range(len(data[:500])):
#       9 #     nouns = get_all_nouns(data[i]['tweet'], 2)
# ---> 10     nouns = nltk_nouns(data[i]['tweet'])
#      11     for noun in nouns:
#      12         noun_day_count[noun][data[i]['date']] += 1
#
# <ipython-input-165-04ef8e4997dd> in nltk_nouns(data)
#      13
#      14 def nltk_nouns(data):
# ---> 15     nlp = spacy.load('en_core_web_sm')
#      16     sen_noun = []
#      17     sentence = data
#
# ~/opt/anaconda3/lib/python3.7/site-packages/spacy/__init__.py in load(name, **overrides)
#      28     if depr_path not in (True, False, None):
#      29         deprecation_warning(Warnings.W001.format(path=depr_path))
# ---> 30     return util.load_model(name, **overrides)
#      31
#      32
#
# ~/opt/anaconda3/lib/python3.7/site-packages/spacy/util.py in load_model(name, **overrides)
#     162             return load_model_from_link(name, **overrides)
#     163         if is_package(name):  # installed as package
# --> 164             return load_model_from_package(name, **overrides)
#     165         if Path(name).exists():  # path to model data directory
#     166             return load_model_from_path(Path(name), **overrides)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/spacy/util.py in load_model_from_package(name, **overrides)
#     183     """Load a model from an installed package."""
#     184     cls = importlib.import_module(name)
# --> 185     return cls.load(**overrides)
#     186
#     187
#
# ~/opt/anaconda3/lib/python3.7/site-packages/en_core_web_sm/__init__.py in load(**overrides)
#      10
#      11 def load(**overrides):
# ---> 12     return load_model_from_init_py(__file__, **overrides)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/spacy/util.py in load_model_from_init_py(init_file, **overrides)
#     226     if not model_path.exists():
#     227         raise IOError(Errors.E052.format(path=path2str(data_path)))
# --> 228     return load_model_from_path(data_path, meta, **overrides)
#     229
#     230
#
# ~/opt/anaconda3/lib/python3.7/site-packages/spacy/util.py in load_model_from_path(model_path, meta, **overrides)
#     195     lang = meta.get("lang_factory", meta["lang"])
#     196     cls = get_lang_class(lang)
# --> 197     nlp = cls(meta=meta, **overrides)
#     198     pipeline = meta.get("pipeline", [])
#     199     factories = meta.get("factories", {})
#
# ~/opt/anaconda3/lib/python3.7/site-packages/spacy/language.py in __init__(self, vocab, make_doc, max_length, meta, **kwargs)
#     175         if make_doc is True:
#     176             factory = self.Defaults.create_tokenizer
# --> 177             make_doc = factory(self, **meta.get("tokenizer", {}))
#     178         self.tokenizer = make_doc
#     179         self.pipeline = []
#
# ~/opt/anaconda3/lib/python3.7/site-packages/spacy/language.py in create_tokenizer(cls, nlp)
#     102             suffix_search=suffix_search,
#     103             infix_finditer=infix_finditer,
# --> 104             token_match=token_match,
#     105         )
#     106
#
# tokenizer.pyx in spacy.tokenizer.Tokenizer.__init__()
#
# tokenizer.pyx in spacy.tokenizer.Tokenizer._load_special_tokenization()
#
# tokenizer.pyx in spacy.tokenizer.Tokenizer.add_special_case()
#
# vocab.pyx in spacy.vocab.Vocab.make_fused_token()
#
# vocab.pyx in spacy.vocab.Vocab.get_by_orth()
#
# vocab.pyx in spacy.vocab.Vocab._new_lexeme()
#
# ~/opt/anaconda3/lib/python3.7/site-packages/spacy/lang/lex_attrs.py in lower(string)
#     175
#     176
# --> 177 def lower(string):
#     178     return string.lower()
#     179
#
# KeyboardInterrupt:

# %%
####################################################################################################
# Dict with day count of named entities using NLTK
####################################################################################################

# !pip install dill
# Note dill required for dumping this type of dictionary (Any dump with lambda calc requires dill as pickle)
noun_day_count['Ransomware']
# import dill 
import dill as pickle
# try:
#     import cPickle as pickle
# except ImportError:  # python 3.x
#     import pickle

s =  pickle.dumps(lambda: defaultdict(lambda:0))
with open('noun_day_count.p', 'wb') as fp:
    pickle.dump(noun_day_count, fp, protocol=pickle.HIGHEST_PROTOCOL)

# %%
# Loads the dictionary from memory
import dill as pickle

with open('noun_day_count.p', 'rb') as fp:
    noun_day_count = pickle.load(fp)

# %%
####################################################################################################
# Dict with day count of named entities using spacy
####################################################################################################

spacy_all_nouns
import dill as pickle

s =  pickle.dumps(lambda: defaultdict(lambda:0))
with open('spacy_all_nouns.p', 'wb') as fp:
    pickle.dump(spacy_all_nouns, fp, protocol=pickle.HIGHEST_PROTOCOL)

# %%
# add three quotes after function name
print(__doc__)

# %%
# noun_day_count

# %%
# noun_day_count['malware']
data[0]['date']
# Out:
# '2020-05-14'

# %%
##############################################################################################################
# Pulling out every hashtag and @mentions from a Tweet
##############################################################################################################

import re

# Data is only a string, not dictionary element
def ret_hash_at (data):
    hashes = re.findall('#\w+', data)   # #\w+ is a regular expression for removing words starting with #
    ats = re.findall('@\w+', data)      # @\w+ is a regular expression for removing words starting with @
    # m = re.search('#\w+', data_list[28]['text'])  # Search used for checking existence, stops after finding first match, will skip any subsequent parts of the string
    # m.group(0)
    return (hashes, ats)

# %%
noun_list = noun
len(set(noun)), len(noun)
# noun_list = noun_listt
# nltk_nouns(data[0]['tweet'])
data[0]
# Out:
# {'train_id': 3326,
#  'relevant': 1,
#  'created_at': 1579756369000,
#  'date': '2020-01-22',
#  'time': '21:12:49',
#  'timezone': 'Pacific Standard Time',
#  'user_id': 134680773,
#  'username': 'rajavardhan87',
#  'name': 'RAJAVARDHAN REDDY',
#  'place': '',
#  'tweet': ".@FireEye and @Citrix have released a new tool to help organizations identify compromised systems associated with the CVE-2019-19781 vulnerability. Learn more about the free tool that's available on FireEye and Citrix GitHub repositories.  http://bit.ly/2TLZJUZ   pic.twitter.com/JYr2PyxkpO",
#  'mentions': "['fireeye', 'citrix']",
#  'urls': "['http://bit.ly/2TLZJUZ']",
#  'replies_count': 0,
#  'retweets_count': 0,
#  'likes_count': 0,
#  'hashtags': '[]',
#  'cashtags': '[]',
#  'link': 'https://twitter.com/rajavardhan87/status/1220',
#  'retweet': 0,
#  'video': '0',
#  'near': '',
#  'geo': '',
#  'source': '',
#  'user_rt_id': 0,
#  'user_rt': '',
#  'retweet_id': 0,
#  'reply_to': "[{'user_id': '134680773', 'username': 'rajava",
#  'retweet_date': '',
#  'translate': '',
#  'trans_src': '',
#  'trans_dest': '',
#  'photos': "['https://pbs.twimg.com/media/EO8RC-iUcAASROp.png']",
#  'conversation_id': '1220212769825251330',
#  'id': '1220212769825251330'}

# %%
################################################################################################
# Neo4j test for noun as node (required another db to store tweet)
# Note we only create nodes here and not the relationships
################################################################################################

from neo4j import GraphDatabase
import json
#Indicate to driver where neo4j is running
driver = GraphDatabase.driver("bolt://localhost:7687",auth=("test_user","password"), encrypted=False)

# idd = 2
with driver.session() as session:
    tx = session.begin_transaction()
    count = 0
    idd = 0
    for tweet_data in data[:1]:
#         tx.run('''Match (a:Tweet {type: $word}) return a.num''', word=noun)
        nouns = nltk_nouns(tweet_data['tweet'])
        for noun in nouns:
            result = tx.run('''Match (a:Tweet {type: $word}) return a''', word=noun.lower())
            result = result.records()
            flag = True
            date = tweet_data['date']
            date = "2020-04-14"
#             print(date)
            for record in result:
                flag = False
                find_index = -1
                for i in range ( len( record['a']['last10DaysDate'] )):
                    if record['a']['last10DaysDate'][i] == date:
                        find_index = i
                        break
                if find_index != -1:
                    tx.run('''MATCH (a:Tweet {type:$word}) SET a.num = a.num+1, a.last10DaysCount = 
                    a.last10DaysCount[ ..$index ] + (a.last10DaysCount[ $index ] + 1) + a.last10DaysCount[ $index+1.. ] ''', word=noun.lower(), index = find_index)
                else:
                    tx.run('''MATCH (a:Tweet {type:$word}) SET a.num = a.num+1, a.last10DaysDate = a.last10DaysDate + [$date], a.last10DaysCount = a.last10DaysCount + [1]''', word=noun.lower(), date=date)
            if flag:
                tx.run('''CREATE (a:Tweet {type:$word, num:1, id:$idd, last10DaysDate:[$date], last10DaysCount:[1]})''', word=noun.lower(), idd=idd, date=date)
                idd += 1
            tx.run('''Match (a:Tweet), (b:Tweet) where $noun = a.type and $noun = b.type
                        merge (a)-[r: encountred_with {type: $noun}]->(b)''', noun=noun.lower())
            #Batch processing to run 1000 tweets as a time as these commits are quite time intensive
        count += 1
        if count > 1000:
            tx.commit()
            tx = session.begin_transaction()
            count = 0
    tx.commit()

# %%
################################################################################################
# Test for loading results  from db for match on word (Named entity)
################################################################################################

from neo4j import GraphDatabase
import json
#Indicate to driver where neo4j is running
driver = GraphDatabase.driver("bolt://localhost:7687",auth=("test_user","password"), encrypted=False)

# driver = GraphDatabase.driver("bolt://localhost",auth=("test_user","password"))
x = None
with driver.session() as session:
    tx = session.begin_transaction()
#     for i in range(len())
    result = tx.run('''Match (a:Tweet {id: 1}) return a''')
    result = result.records()
#     result = tx.run('''Match (a:Tweet {id: 1}) return a''', word=noun)
#     x = result.records()

# %%
y = []
for i in result:
    y.append(i)
#     print(i['id'])
y

# %%
y[0].data()
y[0]['a'].items()
y[0]['a']['last10DaysDate']

# %%
last10DaysDate =  ['12-10-2019', '12-10-2029', '12-10-2010's]
# ["foo", "bar", "baz"].index("bar")
sorted(last10DaysDate)

# %%
y[2]['a']['last10DaysDate'].index('12-100-2019')

# %%
def get_methods_callable ( method ):
    object_methods = [method_name for method_name in dir( method )
                      if callable( getattr(y[0]['a'], method ))]
    return ( object_methods )

# %%
#####################################################################################################
# Neo4j code for forming relations (required another db to store tweet)
# Requires data to be in a 2d array. Inner array is a list of nouns/named entities in the same tweet
#####################################################################################################

from neo4j import GraphDatabase
import json
#Indicate to driver where neo4j is running
driver = GraphDatabase.driver("bolt://localhost:7687",auth=("test_user","password"), encrypted=False)

with driver.session() as session:
    tx = session.begin_transaction()
    count = 0
    for nouns in noun_from_tweet[:1000]:
        for _noun in nouns:
            tx.run('''Match (a:Tweet), (b:Tweet) where $noun = a.type and $noun = b.type
            merge (a)-[r: encountred_with {type: $noun}]->(b)''',
                   noun=_noun.upper()) # add parameters here
        #Batch processing to run 1000 tweets as a time as these commits are quite time intensive
        count += 1
        if count > 1000:
            tx.commit()
            tx = session.begin_transaction()
            count = 0
    tx.commit()

# %%
# Create (x:Tweet{ id:1, noun: 'test', key: 'Value', last10DaysCount:[10], last10DaysDate:["12-10-2019"]  }) return x

################################################################################################
# Neo4j test for noun + Date and Num Count for node type - Requires creating more functionality
# To do: Run New feed with date added as param in aggregation notebook, add code in "for i in x"
# This will be to choose correct array element to increment as hash maps are not allowed inside
# a list in neo4
################################################################################################

### Create data model
### Final Pipeline = Modularize + high level

from neo4j import GraphDatabase
import json

#Indicate to driver where neo4j is running
driver = GraphDatabase.driver("bolt://localhost:7687",auth=("test_user","password"), encrypted=False)

# idd = 2
with driver.session() as session:
    tx = session.begin_transaction()
    count = 0
    idd = 0
    for noun in noun_list[30000:40000]:
#         tx.run('''Match (a:Tweet {type: $word}) return a.num''', word=noun)
        result = tx.run('''Match (a:Tweet {type: $word}) return a.num''', word=noun)
        x = result.records()
        flag = True
        for i in x:
            flag = False
            tx.run('''MATCH (a:Tweet {type:$word}) SET a.num = a.num+1''', word=noun)
        if flag:
            tx.run('''CREATE (a:Tweet {type:$word, num:1, id:$idd, last10DaysCount:[1], last10DaysDate:[$date]})''', word=noun, idd=idd, date=date)
            idd += 1
        #Batch processing to run 1000 tweets as a time as these commits are quite time intensive
    count += 1
    if count > 1000:
        tx.commit()
        tx = session.begin_transaction()
        count = 0
    tx.commit()

# %%
# print(result.single()[0])
# result.single()[0]
type(result)
# result.single()[0] == None
# result.single()
print(type(x))
for i in x:
    print('inside')
    print(i.value() == None)

# %%
xx = []
for i in x:
    xx.append(i)

# %%
# y = hash(xx)
xx[2].value(key=1)
# xx[2]
# y[-6685369989889550852]

# %%
xx[2][1].items()

# %%
count = 0
for i in range(len(noun)):
    for j in range(len(noun[i])):
        if ('Malware' == noun[i][j]):
            count += 1
count

# %%
# !python -m spacy download en
# !python -m spacy download en_core_web_sm

import spacy
nlp = spacy.load('en_core_web_sm')
sentence = "CVE-2019-897 NSA exploit EternalRomance 'formed basis for alleged Chinese tool' - iTWire Researchers Mark Lechtik and Nadav Grossman said in first offered NSA exploits that the hacking group, known variously as APT3 and Gothic Panda, had based its exploitation tool, https://ift.tt/2HRG9js"
doc = nlp(sentence)
print("The sentence is: ", sentence)
# print([ent for ent in doc.ents])
# for ent in doc.ents:
# doc
print("Noun phrases:", [chunk.text for chunk in doc.noun_chunks])
print("Verbs:", [token.lemma_ for token in doc if token.pos_ == "VERB"])
for ent in doc.ents:
    print(ent.text, ent.label_)
print([chunk.text for chunk in doc.noun_chunks])

# %%
################################################################################################
# List of words to remove from matched named entities
################################################################################################

pronouns = """all
another
any
anybody
anyone
anything
as
aught
both
each
each other
either
enough
everybody
everyone
everything
few
he
her
hers
herself
him
himself
his
I
idem
it
its
itself
many
me
mine
most
my
myself
naught
neither
no one
nobody
none
nothing
nought
one
one another
other
others
ought
our
ours
ourself
ourselves
several
she
some
somebody
someone
something
somewhat
such
suchlike
that
thee
their
theirs
theirself
theirselves
them
themself
themselves
there
these
they
thine
this
those
thou
thy
thyself
us
we
what
whatever
whatnot
whatsoever
whence
where
whereby
wherefrom
wherein
whereinto
whereof
whereon
wherever
wheresoever
whereto
whereunto
wherewith
wherewithal
whether
which
whichever
whichsoever
who
whoever
whom
whomever
whomso
whomsoever
whose
whosever
whosesoever
whoso
whosoever
ye
yon
yonder
you
your
yours
yourself
yourselves"""

extra_words = ['the']
pronouns = pronouns.split("\n")
pronouns

# %%
print("Verbs:", [token.lemma_ for token in doc if token.pos_ == "VERB"])

# %%
for entity in doc.ents:
    print(entity.text, entity.label_)

# %%
doc.ents

# %%
################################################################################################
# Documentation on establishing a connection using the Twitter API
################################################################################################

# oauth_consumer_key - ZYOj2R1VYsIUhaRvsrcRuHxk6
# oauth_nonce	kYjzVBB8Y0ZFabxSWbWovY3uYSQ2pTgmZeNu2VS4cg
# Consumer Secret = API Secret Key = uTwMxW2CPXfv8wZCcqOSX8Yw46eqJVMNopqh5kh9O0VXiVQNRG
# Access token secret = OAuth token secret: VB6fxb1akdtwRDf52sbQlPKE9tpHEPX1ZBSI3Y1t33REk
# Signing key = uTwMxW2CPXfv8wZCcqOSX8Yw46eqJVMNopqh5kh9O0VXiVQNRG&VB6fxb1akdtwRDf52sbQlPKE9tpHEPX1ZBSI3Y1t33REk
# oauth-token = 797644398670409728-I3aUqpmhD7uPscfFZFxMGfMWXPBmiaN
# oauth_signature = Use HMAC
# curl -XPOST 
#   --url 'https://api.twitter.com/1.1/statuses/update.json?status=hello' 
#   --header 'authorization: OAuth
#   oauth_consumer_key="oauth_customer_key",
#   oauth_nonce="generated_oauth_nonce",
#   oauth_signature="generated_oauth_signature",
#   oauth_signature_method="HMAC-SHA1",
#   oauth_timestamp="generated_timestamp",
#   oauth_token="797644398670409728-I3aUqpmhD7uPscfFZFxMGfMWXPBmiaN",
#   oauth_version="1.0"'

# NEW KEYS: (DO NOT SHARE)
# Access token :797644398670409728-Zwgcl9kcCFerhFNlFFGwR3emSbfpfpX
# Copy
# Access token secret :CzVCCqD8X9FC059X98deDiNYb24IWjhZYVeAhoU4F5v7l
# Copy

# %%
#####################################################################################################
# Twitter API Connection established
#####################################################################################################

import twitter
api = twitter.Api(consumer_key="ZYOj2R1VYsIUhaRvsrcRuHxk6",
                  consumer_secret="uTwMxW2CPXfv8wZCcqOSX8Yw46eqJVMNopqh5kh9O0VXiVQNRG",
                  access_token_key="797644398670409728-Zwgcl9kcCFerhFNlFFGwR3emSbfpfpX",
                  access_token_secret="CzVCCqD8X9FC059X98deDiNYb24IWjhZYVeAhoU4F5v7l")

# %%
results = api.GetSearch(
    raw_query="q=from%3Atwitterdev&result_type=mixed&count=2&tweet_mode=extended")

# %%
# results[27].AsJsonString
x = results[0].AsDict()

# %%
#  dir(twitter.models.Status)
# x

# %%
>>> api.GetSearch(geocode=[37.781157, -122.398720, "1mi"])

# %%
data

# %%
from collections import defaultdict    
    
def frequency_of_word (tweet):
    tweet = tweet.lower().replace('\n','').replace("#"," ").split(" ")
    dic = defaultdict(lambda: 0)
    for word in tweet:
        if (word == ''):
            continue
        dic[word] += 1
    return dic

# %%
data[0], data[-1]
# data[0]['created_at'], data[-1]['created_at']

# %%
# Note velocity is calculated for 10 (arbitrary) tweets at a time
from math import exp
# Note make window size to be 10 tweets (10 time stamps) - Process similar to calculated Exponential moving average (EMA) for stocks
# This gives velocity for each word

def velocity (data_elem, word_freq, time_t, delta_t):  #note time is the time till which you fetched tweets, delta_t is the time interval over which tweets were fetched
#     dic = frequency_of_word(data_elem['tweet'])
    inner_product = exp( (data_elem['created_at'] - time_t)/delta_t )/delta_t
    return (inner_product * word_freq)
# Out:
#   File "<ipython-input-71-5db8b4e8980c>", line 9
#     inner_product =
#                     ^
# SyntaxError: invalid syntax

# %%
# Make a func for sending tweets in batches of 10 to velocity

# %%
help(eval)
# Out:
# Help on built-in function eval in module builtins:
#
# eval(source, globals=None, locals=None, /)
#     Evaluate the given source in the context of globals and locals.
#
#     The source may be a string representing a Python expression
#     or a code object as returned by compile().
#     The globals must be a dictionary and locals can be any mapping,
#     defaulting to the current globals and locals.
#     If only globals is given, locals defaults to it.

# %%
def create_m2 (tweets):
    
def process_m2_unit(self, _count, _n_words, _h):
        s = _n_words * (_n_words - 1.0)

        n_distinct_words = len(_count)
        #simplifies counting of pairs for x_i (Do not need to actually generate the pairs with this)
        for k1 in _count:
            for k2 in _count:
                if k1 > k2:
                    continue
                if k1 == k2:
                    num = _count[k1] * (_count[k1] - 1)
                else:
                    num = _count[k1] * _count[k2]

                if num == 0:
                    continue
                #laplace gives back the frequency of a word in the matrix with laplace smoothing applied
                num = self.laplace_smooth(num, s, n_distinct_words ** 2, self.alpha2)

                self.sketch_m2[_h].get(self._index(k1, k2), self.timestamp).observe(self.timestamp, num)

    def laplace_smooth(x1, x2, n, alpha=1.):
        return (x1 + alpha) / (x2 + n * alpha)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-68-d0a520c3047a> in <module>
#       5 HASH_NUMBER = 5
#       6
# ----> 7 hashBase.initialize(HASH_NUMBER)
#       8
#       9
#
# NameError: name 'hashBase' is not defined

# %%
import numpy as np
j = 3
temp_matrix = np.asarray( j * [([0]*j)] )
for k in range(j):
    temp_matrix[k][j-k-1] = temp_dict[temp_dict_keysn[k]]
# data[1]['tweet']
temp_matrix
# Out:
# array([[0, 0, 1],
#        [0, 1, 0],
#        [1, 0, 0]])

# %%
import numpy as np

word_pair_freq_matrix = []
for i in range(len(data[:1])):
    temp_dict = frequency_of_word(data[i]['tweet'])
    temp_dict_keys = list(temp_dict.keys())
    j = len(temp_dict_keys)
    temp_matrix = np.asarray( j * [([0]*j)] )
    for k in range(j):
        temp_matrix[k][j-k-1] = temp_dict[temp_dict_keys[k]]
#         print(temp_matrix[k], temp_matrix[k+1])
#         break
    word_pair_freq_matrix.append(temp_matrix)

# %%
word_pair_freq_matrix
data_copy = data

# %%
from sklearn.feature_extraction import DictVectorizer
from collections import Counter, OrderedDict

File_1 = ('aaa', 'xyz', 'cccc', 'dddd', 'aaa')
File_2 = ('abc', 'aaa')

v = DictVectorizer()

# discover corpus and vectorize file word frequencies in a single pass
X = v.fit_transform(Counter(f) for f in (File_1, File_2))
# or, if you have a pre-defined corpus and/or would like to restrict the words you consider
# in your matrix, you can do
# Corpus = ('aaa', 'bbb', 'cccc', 'dddd', 'xyz')

# v.fit([OrderedDict.fromkeys(Corpus, 1)])
# X = v.transform(Counter(f) for f in (File_1, File_2))

# X is a sparse matrix, but you can access the A property to get a dense numpy.ndarray 

# representation

print(X)

print(X.A)

# <2x5 sparse matrix of type '<type 'numpy.float64'>'
# Out:
#   (0, 0)	2.0
#   (0, 2)	1.0
#   (0, 3)	1.0
#   (0, 4)	1.0
#   (1, 0)	1.0
#   (1, 1)	1.0
# [[2. 0. 1. 1. 1.]
#  [1. 1. 0. 0. 0.]]

# %%
################################################################################################
# Neo4j test for noun as node (required another db to store tweet)
# Note we only create nodes here and not the relationships
################################################################################################

from neo4j import GraphDatabase
import json

def fetchDriver():
    #Indicate to driver where neo4j is running
    driver = GraphDatabase.driver("bolt://localhost:7687",auth=("test_user","password"), encrypted=False)
    return driver

def addToGraph(driver,tweet_data):
    # idd = 2
    with driver.session() as session:
        tx = session.begin_transaction()
        count = 0
        idd = 1000
#         tx.run('''Match (a:Tweet {type: $word}) return a.num''', word=noun)
        nouns = nltk_nouns(tweet_data['tweet'])
        for noun in nouns:
            result = tx.run('''Match (a:Tweet {type: $word}) return a''', word=noun.lower())
            result = result.records()
            flag = True
            date = tweet_data['date']
            date = "2020-04-14"
#             print(date)
            for record in result:
                flag = False
                find_index = -1
                for i in range ( len( record['a']['last10DaysDate'] )):
                    if record['a']['last10DaysDate'][i] == date:
                        find_index = i
                        break
                if find_index != -1:
                    tx.run('''MATCH (a:Tweet {type:$word}) SET a.num = a.num+1, a.last10DaysCount =
                    a.last10DaysCount[ ..$index ] + (a.last10DaysCount[ $index ] + 1) + a.last10DaysCount[ $index+1.. ] ''', word=noun.lower(), index = find_index)
                else:
                    tx.run('''MATCH (a:Tweet {type:$word}) SET a.num = a.num+1, a.last10DaysDate = a.last10DaysDate + [$date], a.last10DaysCount = a.last10DaysCount + [1]''', word=noun.lower(), date=date)
            if flag:
                tx.run('''CREATE (a:Tweet {type:$word, num:1, id:$idd, last10DaysDate:[$date], last10DaysCount:[1]})''', word=noun.lower(), idd=idd, date=date)
                idd += 1
            tx.run('''Match (a:Tweet), (b:Tweet) where $noun = a.type and $noun = b.type
                        merge (a)-[r: encountred_with {type: $noun}]->(b)''', noun=noun.lower())

        tx.commit()

# %%
# f[word1][word2]
x = fetchDriver()
addToGraph
